# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # HandsOn 1 - Plots and Grids

# %%
x = [_ for _ in range(0,10)]
y = [_*_ for _ in range(0,10)]
fig = plt.figure()   # create a figure
ax = fig.gca()  # get current axes
ax.set_xticks(np.arange(0,10,1))
ax.set_yticks(np.arange(0,100,10))
plt.scatter(x,y)
plt.grid()
plt.show()

# %% [markdown]
# ## HandsOn 2 - Markers

# %%
# plt.plot([x for x in range(0,10)], marker = 'P')   # looks like plus symbol
plt.plot([x for x in range(0,10)], marker = 'D')   # looks like diamond symbol

# %% [markdown]
# # HandsOn 3 - Colors

# %%
plt.plot([x*x for x in range(0,10)], 'red', marker = 'P')
plt.plot([x*x for x in range(9,-1,-1)], 'blue', marker = 'p')

# %% [markdown]
# ## HandsOn 4 - Fonts

# %%
plt.title("Cube of Numbers from 0 to 9", fontname= 'Comic Sans MS', fontsize=18)
plt.xlabel("Numbers from 0 to 9", fontname= 'Arial', fontsize = 12)
plt.ylabel("Cube of numbers on x axis", fontname='sans-serif', fontsize = 12)
plt.plot([x*x*x for x in range(0,10)], 'cyan', marker='P')

# %% [markdown]
# ## Hands On 5 - Graphs and Charts

# %%
plt.hist([10,15,15,10,20,20,1,14,10,14,12,14])
plt.show()

# %%
labels = ['Frogs', 'Hogs', 'Dogs', 'Logs']
sizes = [15, 30, 45, 10]
plt.pie(sizes, labels = labels)
plt.show()

# %%
labels = ['Jane', 'John', 'James', 'Johnny']
x_pos = np.arange(len(labels))
data = [55, 25, 28, 45]
plt.bar(x_pos, data)

plt.xticks(x_pos, labels)
plt.xlabel('Name')
plt.ylabel('Age')
plt.title('Name vs Age')
plt.show()

# %% [markdown]
# ## HandsOn 6 - Count Plots

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(x="class", data = titanic)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(y = "class", hue = 'who', data = titanic)
# Out:
# <Axes: xlabel='count', ylabel='class'>

# %% [markdown]
# ## HandsOn 7 - Heatmap

# %%
data = [[99, 85, 15], [78, 5, 25], [90,45,35]]
sns.heatmap(data, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## HandsOn 8 - Colormap

# %%
titanic = sns.load_dataset("titanic")
# sns.countplot(x = 'class', data = titanic, palette = ['red', 'green', 'blue'])  # custom color palette
sns.countplot(x = 'class', data = titanic, palette = 'Purples')  # BuiltIn color palette
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %% [markdown]
# ## Assignment 1

# %% [markdown]
# ###### 1. Start off by importing the cars.csv file in the jupyter notebook.
# ###### 2. Generate a line plot graph for the column ‘model’ and ‘hp’:
# - a. Map the ‘model’ column on the x-axis
# - b. Map the ‘hp’ column on the y-axis
# - c. Provide the x-axis label as Models of the cars
# - d. Provide the y-axis label as Horse-Power of Cars
# - e. Set the title as Model Names vs HorsePower

# %%
df = pd.read_csv("datasets/Dataset/cars (1) (1).csv")
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
plt.plot(df['model'], df['hp'])
plt.xlabel("Models of the cars")
plt.ylabel("Horse-Power of Cars")
plt.xticks(rotation = 90)
plt.title("Model Names vs Horse Power")
plt.show()

# %% [markdown]
# ###### 1. Generate a bar plot graph for the columns ‘carbs’ and ‘gear’:
# - a. Map the ‘carbs’ onto the x-axis
# - b. Map the ‘gear’ onto the y-axis
# - c. Provide the x-axis label as Number of carburetors
# - d. Provide the y-axis label as Number of forward gears
# - e. Set the title as carbs vs gear

# %%
plt.bar(df['carb'], df['gear'])
plt.xlabel("Number of carburetors")
plt.ylabel("Number of forward gears")
plt.title("carb vs gear")
plt.show()

# %% [markdown]
# ###### 1. Plot a histogram for the column ‘wt’:
# - a. Map the ‘wt’ onto the x-axis
# - b. Provide the x-axis label as ‘weight of the cars’
# - c. Provide the y-axis label as ‘Count’
# - d. Set the number of bins as 30
# - e. Set the title as ‘Histogram for the weight values’

# %%
plt.hist(df['wt'], bins = 30)
plt.xlabel("weight of the cars")
plt.ylabel("Count")
plt.title("Histogram for the weight values")
plt.show()

# %% [markdown]
# ###### 1. Plot a pie chart for columns: ‘cyl’ and ‘model’ form the mtcars.csv data frame.

# %%
mtcars = pd.read_csv("datasets/mtcars2.csv")
mtcars.rename(columns={'Unnamed: 1': 'model'}, inplace = True)
mtcars.head()
# Out:
#    S.No              model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0     1          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1     2      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2     3         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3     4     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     5  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2

# %%
# mtcars['model'].value_counts()
mtcars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   S.No    32 non-null     int64
#  1   model   32 non-null     object
#  2   mpg     32 non-null     float64
#  3   cyl     32 non-null     int64
#  4   disp    32 non-null     float64
#  5   hp      32 non-null     int64
#  6   drat    32 non-null     float64
#  7   wt      32 non-null     float64
#  8   qsec    29 non-null     float64
#  9   vs      32 non-null     int64
#  10  am      32 non-null     int64
#  11  gear    32 non-null     int64
#  12  carb    32 non-null     int64
# dtypes: float64(5), int64(7), object(1)
# memory usage: 3.4+ KB

# %%
plt.pie(mtcars['cyl'], labels=mtcars['model']);

# %%
newdf = mtcars.groupby('cyl', as_index = False)['cyl'].value_counts()
# cylinders = newdf
newdf
# Out:
#    cyl  count
# 0    4     11
# 1    6      7
# 2    8     14

# %%
labels = []
for i in newdf['cyl']:
    labels.append([x for x in mtcars[mtcars['cyl'] == i]['model']])
# fig1, ax1 = plt.subplots(figsize=(8,12))
# wdges, labels, autopct  = ax1.pie(newdf['cyl'], labels = labels, 
#                         radius=1,
#     startangle=90,
#     counterclock=False,
#     shadow=False,
#     wedgeprops={'edgecolor': 'white', 'linewidth': 1},
#     textprops={'fontsize': 8},
#     pctdistance=0.85,
#     autopct='%1.1f%%')
# plt.setp(labels, fontsize=15) 
# plt.tight_layout()
plt.pie(newdf['cyl'], labels = labels);

# %% [markdown]
# ###### 1. Plot the area chart for the columns ‘am’ and ‘carb’:
# - a. Set the ‘am’ on the x-axis
# - b. Set the ‘carb’ on the y-axis
# - c. Provide the x-axis label as Transmission
# - d. Provide the y-axis label as Number of carburetors
# - e. Provide the title as Transmission vs Number of carburetors

# %%
plt.figure(figsize = (10,4))
plt.stackplot(range(1, mtcars.count()[0]+1),mtcars['am'], mtcars['carb'])
plt.xlabel("Transmission")
plt.ylabel("Number of carburetors")
plt.title("Transmission vs Number of carburetors")
plt.xticks(range(1, mtcars.count()[0]+1))
# plt.yticks(range(0, 31, 5))
plt.show()

# %%
plt.fill_between(df['am'], df['carb'])
plt.xlabel("Transmission")
plt.ylabel("Number of carburetors")
plt.title("Transmission vs Number of carburetors")
# Out:
# Text(0.5, 1.0, 'Transmission vs Number of carburetors')

# %% [markdown]
# ## Case Study 1 - Data Visualization

# %%
df = pd.read_csv("datasets/Dataset/customer_churn.csv")
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# ###### 1. Sam has to build a bar-plot for the ‘Contract’ column:
# - a. Set the x-axis label to be ‘Contract Type of customer’
# - b. Set the y-axis label to be ‘Count’
# - c. Set the title of the plot to be ‘Distribution of Contract’
# - d. Assign ‘orange’ color to all the bars

# %%
cdf = df['Contract'].value_counts()
keys = (dict(cdf.items())).keys()
values = (dict(cdf.items())).values()
plt.bar(keys, values, color = 'orange')
plt.xlabel('Contract Type of customer')
plt.ylabel('Count')
plt.title("Distribution of Contract")
plt.show()

# %%
df['Contract'].value_counts().plot(kind = 'barh', color = 'orange')
# Out:
# <Axes: >

# %% [markdown]
# ###### 2. Sam has to build a histogram for the ‘MonthlyCharges’ column:
# - a. Set the x-axis label to be ‘Monthly Charges Incurred’
# - b. Set the y-axis label to be ‘Count’
# - c. Set the title of the plot to be ‘Distribution of Monthly Charges’
# - d. Assign ‘forestgreen’ color to the bins

# %%
plt.hist(df['MonthlyCharges'], color = 'forestgreen')
plt.xlabel("Monthly Charges Incurred")
plt.ylabel("Count")
plt.title("Distribution of Monthly Charges")
plt.show()

# %% [markdown]
# ###### 3. Sam has to build a scatter-plot between ‘TotalCharges’ and ‘tenure’.
# - ‘TotalCharges’ should be on the y-axis and ‘tenure’ should be on the x-axis.
# - a. Set the x-axis label to be ‘Tenure of the customer’
# - b. Set the y-axis label to be ‘Total chargesIncurred’
# - c. Set the title of the plot to be ‘Total Charges vs Tenure’
# - d. Assign ‘indigo’ color to the points

# %%
plt.scatter(df['tenure'], df['TotalCharges'], color='indigo', marker = 'P')
plt.xlabel('Tenure of the customer')
plt.ylabel('Total charges Incurred')
plt.title("Total Charges vs Tenure")
plt.show()

# %%
df['tenure'].value_counts(), df['MonthlyCharges'].value_counts()
# Out:
# (1     613
#  72    362
#  2     238
#  3     200
#  4     176
#       ...
#  28     57
#  39     56
#  44     51
#  36     50
#  0      11
#  Name: tenure, Length: 73, dtype: int64,
#  20.05     61
#  19.85     45
#  19.95     44
#  19.90     44
#  20.00     43
#            ..
#  23.65      1
#  114.70     1
#  43.65      1
#  87.80      1
#  78.70      1
#  Name: MonthlyCharges, Length: 1585, dtype: int64)

# %% [markdown]
# ###### 4. Sam has to build a box-plot between ‘MonthlyCharges’ and ‘PaymentMethod’. ‘MonthlyCharges’ should be on the y-axis and ‘PaymentMethod’ should be on the x-axis.
# - a. Set the x-axis label to be ‘Payment Method of customer’
# - b. Set the y-axis label to be ‘Monthly ChargesIncurred’
# - c. Set the title of plot to be ‘Monthly Charges vs. Payment Method’
# - d. Assign ‘olive’ color to the box-plots

# %%
df.shape
# Out:
# (7043, 21)

# %%
# df_melted = pd.melt(df[ ['PaymentMethod', 'MonthlyCharges']])
# df_melted
# df_melted.value = df_melted.value.astype('int32')
# df_melted['value'].value_counts()
ax = sns.boxplot(x='PaymentMethod', y='MonthlyCharges', data=df)
ax.set_xticklabels(ax.get_xticklabels() , rotation = 30)
plt.xlabel('Payment Method of customer')
plt.ylabel("Monthly Charges Incurred")
plt.title("Monthly Charges vs Payment Method")
plt.show()

# %% [markdown]
# ## Case Study 2 - Data Visualization

# %% [markdown]
# ###### 1. Load cars data as dataframe using pandas and create a bar plot between number of cylinders and frequency of cars with that many number of cylinders
# - ● Set xlabel as Number of cylinders
# - ● Set ylabel as Frequency of cars
# - ● Draw a bar plot

# %%
cars = pd.read_csv("datasets/mtcars2.csv")
cars.columns
# Out:
# Index(['S.No', 'Unnamed: 1', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec',
#        'vs', 'am', 'gear', 'carb'],
#       dtype='object')

# %%
ax = cars.cyl.value_counts().plot(kind='barh')
# ax.set_xscale('log')

# %% [markdown]
# ###### 2. Write code to load data from cars and print a bar graph of count of columns with null values.

# %%
cars.isnull().value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='S.No,Unnamed: 1,mpg,cyl,disp,hp,drat,wt,qsec,vs,am,gear,carb'>

# %%
cars.isnull().sum()
# Out:
# S.No          0
# Unnamed: 1    0
# mpg           0
# cyl           0
# disp          0
# hp            0
# drat          0
# wt            0
# qsec          3
# vs            0
# am            0
# gear          0
# carb          0
# dtype: int64

# %% [markdown]
# ###### 3. Use the 'mpg' (Miles Per Gallon column) and draw a histogram:
# - ● Set xlabel: Miles per gallon
# - ● Set ylabel: Frequency
# - ● Set title as Miles Per Gallon Histogram
# - ● Use mpg column to generate a histogram

# %%
plt.hist(cars['mpg'])
plt.xlabel("Miles per gallon")
plt.ylabel("Frequency")
plt.title("Miles Per Gallon Histogram");

# %% [markdown]
# ###### 4. Draw a boxplot on the card dataframes hp column:
# - ● Set xlabel: Car Horsepower
# - ● Set title as Boxplot for car horsepower
# - ● Use hp column to generate a boxplot

# %%
plt.boxplot(cars['hp'])
plt.xlabel("Car Horsepower")
plt.title("Boxplot for car Horsepower")
# Out:
# Text(0.5, 1.0, 'Boxplot for car Horsepower')
